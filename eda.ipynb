# %%
import pandas as pd

data = pd.read_csv("C:\\Users\\SimoesLabAdmin\\Documents\\pyrate_workshop\\pbdb_data.csv")
data.isna().sum()
# Out:
# Species    0
# Status     0
# min_age    0
# max_age    0
# dtype: int64
