# %%
import pandas as pd

# %%
data = pd.read_csv("C:\\Users\\SimoesLabAdmin\\Documents\\pyrate_workshop\\pbdb_data.csv")
data.isna().sum()
# Out:
# occurrence_no         0
# record_type           0
# reid_no            1149
# flags               712
# collection_no         0
# accepted_name         0
# accepted_rank         0
# accepted_no           0
# early_interval        0
# late_interval      1086
# max_ma                0
# min_ma                0
# reference_no          0
# in_large_period       0
# in_small_period       0
# Unnamed: 15        1293
# unique_genera      1292
# dtype: int64

# %%
species =  pd.read_csv("pbdb_data_TaxonList.txt", sep="\t")

lat_species = pd.read_csv("C:\\Users\\SimoesLabAdmin\\Documents\\pt_diversity_rates\\updated_occurrence_analyses\\data\\Perm-Trias\\bdnn_trait_files\\pt_reptilia_all_lats_file_final.csv")

# check that all species["Species"] are in lat_species["genus"]

for sp in species["Species"]:
    if sp not in lat_species["genus"].values:
        print(sp)
# Out:
# Aetosauripus
# Anchisauripus
# Argoides
# Atreipus
# Barrancapus
# Basutodon
# Brachychirotherium
# Californosaurus
# Carmelopodus
# Chelonipus
# Coelurosaurichnus
# Delatorrichnus
# Deuterotrisauropus
# Dilophosauripus
# Dromopus
# Eosauropus
# Eubrontes
# Evazoum
# Gregaripus
# Gwyneddichnium
# Hamatopus
# Hyloidichnus
# Ingenierichnus
# Isochirotherium
# Kayentapus
# Lagosuchus
# Longosuchus
# Mafatrisauropus
# Megalosauripus
# Mehliella
# Nectosaurus
# Otozoum
# Pachypes
# Parabrontopodus
# Parachirotherium
# Parasynaptichnium
# Pengxianpus
# Phalangichnus
# Plectropterna
# Prochirotherium
# Promystriosuchus
# Prorotodactylus
# Protochirotherium
# Pseudotetrasauropus
# Rhynchosauroides
# Rigalites
# Rotodactylus
# Shenmuichnus
# Stenonyx
# Steropoides
# Synaptichnium
# Tetrasauropus
# Wintonopus
